# %%
# import

import pandas as pd
from quickdraw import QuickDrawData, QuickDrawing
from dataclasses import dataclass, asdict
from PIL import Image, ImageChops, ImageDraw, ImageFont
from pprint import pprint
import numpy as np
import random
import os

# %%
label_info = pd.read_csv("../labels.csv")
coco_info = pd.read_csv("../output.csv")

# %%
qd = QuickDrawData()
qd.load_all_drawings()
# Out:
# loading aircraft carrier drawings
# load complete
# loading airplane drawings
# load complete
# loading alarm clock drawings
# load complete
# loading ambulance drawings
# load complete
# loading angel drawings
# load complete
# loading animal migration drawings
# load complete
# loading ant drawings
# load complete
# loading anvil drawings
# load complete
# loading apple drawings
# load complete
# loading arm drawings
# load complete
# loading asparagus drawings
# load complete
# loading axe drawings
# load complete
# loading backpack drawings
# load complete
# loading banana drawings
# load complete
# loading bandage drawings
# load complete
# loading barn drawings
# load complete
# loading baseball bat drawings
# load complete
# loading baseball drawings
# load complete
# loading basket drawings
# load complete
# loading basketball drawings
# load complete
# loading bat drawings
# load complete
# loading bathtub drawings
# load complete
# loading beach drawings
# load complete
# loading bear drawings
# load complete
# loading beard drawings
# load complete
# loading bed drawings
# load complete
# loading bee drawings
# load complete
# loading belt drawings
# load complete
# loading bench drawings
# load complete
# loading bicycle drawings
# load complete
# loading binoculars drawings
# load complete
# loading bird drawings
# load complete
# loading birthday cake drawings
# load complete
# loading blackberry drawings
# load complete
# loading blueberry drawings
# load complete
# loading book drawings
# load complete
# loading boomerang drawings
# load complete
# loading bottlecap drawings
# load complete
# loading bowtie drawings
# load complete
# loading bracelet drawings
# load complete
# loading brain drawings
# load complete
# loading bread drawings
# load complete
# loading bridge drawings
# load complete
# loading broccoli drawings
# load complete
# loading broom drawings
# load complete
# loading bucket drawings
# load complete
# loading bulldozer drawings
# load complete
# loading bus drawings
# load complete
# loading bush drawings
# load complete
# loading butterfly drawings
# load complete
# loading cactus drawings
# load complete
# loading cake drawings
# load complete
# loading calculator drawings
# load complete
# loading calendar drawings
# load complete
# loading camel drawings
# load complete
# loading camera drawings
# load complete
# loading camouflage drawings
# load complete
# loading campfire drawings
# load complete
# loading candle drawings
# load complete
# loading cannon drawings
# load complete
# loading canoe drawings
# load complete
# loading car drawings
# load complete
# loading carrot drawings
# load complete
# loading castle drawings
# load complete
# loading cat drawings
# load complete
# loading ceiling fan drawings
# load complete
# loading cell phone drawings
# load complete
# loading cello drawings
# load complete
# loading chair drawings
# load complete
# loading chandelier drawings
# load complete
# loading church drawings
# load complete
# loading circle drawings
# load complete
# loading clarinet drawings
# load complete
# loading clock drawings
# load complete
# loading cloud drawings
# load complete
# loading coffee cup drawings
# load complete
# loading compass drawings
# load complete
# loading computer drawings
# load complete
# loading cookie drawings
# load complete
# loading cooler drawings
# load complete
# loading couch drawings
# load complete
# loading cow drawings
# load complete
# loading crab drawings
# load complete
# loading crayon drawings
# load complete
# loading crocodile drawings
# load complete
# loading crown drawings
# load complete
# loading cruise ship drawings
# load complete
# loading cup drawings
# load complete
# loading diamond drawings
# load complete
# loading dishwasher drawings
# load complete
# loading diving board drawings
# load complete
# loading dog drawings
# load complete
# loading dolphin drawings
# load complete
# loading donut drawings
# load complete
# loading door drawings
# load complete
# loading dragon drawings
# load complete
# loading dresser drawings
# load complete
# loading drill drawings
# load complete
# loading drums drawings
# load complete
# loading duck drawings
# load complete
# loading dumbbell drawings
# load complete
# loading ear drawings
# load complete
# loading elbow drawings
# load complete
# loading elephant drawings
# load complete
# loading envelope drawings
# load complete
# loading eraser drawings
# load complete
# loading eye drawings
# load complete
# loading eyeglasses drawings
# load complete
# loading face drawings
# load complete
# loading fan drawings
# load complete
# loading feather drawings
# load complete
# loading fence drawings
# load complete
# loading finger drawings
# load complete
# loading fire hydrant drawings
# load complete
# loading fireplace drawings
# load complete
# loading firetruck drawings
# load complete
# loading fish drawings
# load complete
# loading flamingo drawings
# load complete
# loading flashlight drawings
# load complete
# loading flip flops drawings
# load complete
# loading floor lamp drawings
# load complete
# loading flower drawings
# load complete
# loading flying saucer drawings
# load complete
# loading foot drawings
# load complete
# loading fork drawings
# load complete
# loading frog drawings
# load complete
# loading frying pan drawings
# load complete
# loading garden hose drawings
# load complete
# loading garden drawings
# load complete
# loading giraffe drawings
# load complete
# loading goatee drawings
# load complete
# loading golf club drawings
# load complete
# loading grapes drawings
# load complete
# loading grass drawings
# load complete
# loading guitar drawings
# load complete
# loading hamburger drawings
# load complete
# loading hammer drawings
# load complete
# loading hand drawings
# load complete
# loading harp drawings
# load complete
# loading hat drawings
# load complete
# loading headphones drawings
# load complete
# loading hedgehog drawings
# load complete
# loading helicopter drawings
# load complete
# loading helmet drawings
# load complete
# loading hexagon drawings
# load complete
# loading hockey puck drawings
# load complete
# loading hockey stick drawings
# load complete
# loading horse drawings
# load complete
# loading hospital drawings
# load complete
# loading hot air balloon drawings
# load complete
# loading hot dog drawings
# load complete
# loading hot tub drawings
# load complete
# loading hourglass drawings
# load complete
# loading house plant drawings
# load complete
# loading house drawings
# load complete
# loading hurricane drawings
# load complete
# loading ice cream drawings
# load complete
# loading jacket drawings
# load complete
# loading jail drawings
# load complete
# loading kangaroo drawings
# load complete
# loading key drawings
# load complete
# loading keyboard drawings
# load complete
# loading knee drawings
# load complete
# loading knife drawings
# load complete
# loading ladder drawings
# load complete
# loading lantern drawings
# load complete
# loading laptop drawings
# load complete
# loading leaf drawings
# load complete
# loading leg drawings
# load complete
# loading light bulb drawings
# load complete
# loading lighter drawings
# load complete
# loading lighthouse drawings
# load complete
# loading lightning drawings
# load complete
# loading line drawings
# load complete
# loading lion drawings
# load complete
# loading lipstick drawings
# load complete
# loading lobster drawings
# load complete
# loading lollipop drawings
# load complete
# loading mailbox drawings
# load complete
# loading map drawings
# load complete
# loading marker drawings
# load complete
# loading matches drawings
# load complete
# loading megaphone drawings
# load complete
# loading mermaid drawings
# load complete
# loading microphone drawings
# load complete
# loading microwave drawings
# load complete
# loading monkey drawings
# load complete
# loading moon drawings
# load complete
# loading mosquito drawings
# load complete
# loading motorbike drawings
# load complete
# loading mountain drawings
# load complete
# loading mouse drawings
# load complete
# loading moustache drawings
# load complete
# loading mouth drawings
# load complete
# loading mug drawings
# load complete
# loading mushroom drawings
# load complete
# loading nail drawings
# load complete
# loading necklace drawings
# load complete
# loading nose drawings
# load complete
# loading ocean drawings
# load complete
# loading octagon drawings
# load complete
# loading octopus drawings
# load complete
# loading onion drawings
# load complete
# loading oven drawings
# load complete
# loading owl drawings
# load complete
# loading paint can drawings
# load complete
# loading paintbrush drawings
# load complete
# loading palm tree drawings
# load complete
# loading panda drawings
# load complete
# loading pants drawings
# load complete
# loading paper clip drawings
# load complete
# loading parachute drawings
# load complete
# loading parrot drawings
# load complete
# loading passport drawings
# load complete
# loading peanut drawings
# load complete
# loading pear drawings
# load complete
# loading peas drawings
# load complete
# loading pencil drawings
# load complete
# loading penguin drawings
# load complete
# loading piano drawings
# load complete
# loading pickup truck drawings
# load complete
# loading picture frame drawings
# load complete
# loading pig drawings
# load complete
# loading pillow drawings
# load complete
# loading pineapple drawings
# load complete
# loading pizza drawings
# load complete
# loading pliers drawings
# load complete
# loading police car drawings
# load complete
# loading pond drawings
# load complete
# loading pool drawings
# load complete
# loading popsicle drawings
# load complete
# loading postcard drawings
# load complete
# loading potato drawings
# load complete
# loading power outlet drawings
# load complete
# loading purse drawings
# load complete
# loading rabbit drawings
# load complete
# loading raccoon drawings
# load complete
# loading radio drawings
# load complete
# loading rain drawings
# load complete
# loading rainbow drawings
# load complete
# loading rake drawings
# load complete
# loading remote control drawings
# load complete
# loading rhinoceros drawings
# load complete
# loading rifle drawings
# load complete
# loading river drawings
# load complete
# loading roller coaster drawings
# load complete
# loading rollerskates drawings
# load complete
# loading sailboat drawings
# load complete
# loading sandwich drawings
# load complete
# loading saw drawings
# load complete
# loading saxophone drawings
# load complete
# loading school bus drawings
# load complete
# loading scissors drawings
# load complete
# loading scorpion drawings
# load complete
# loading screwdriver drawings
# load complete
# loading sea turtle drawings
# load complete
# loading see saw drawings
# load complete
# loading shark drawings
# load complete
# loading sheep drawings
# load complete
# loading shoe drawings
# load complete
# loading shorts drawings
# load complete
# loading shovel drawings
# load complete
# loading sink drawings
# load complete
# loading skateboard drawings
# load complete
# loading skull drawings
# load complete
# loading skyscraper drawings
# load complete
# loading sleeping bag drawings
# load complete
# loading smiley face drawings
# load complete
# loading snail drawings
# load complete
# loading snake drawings
# load complete
# loading snorkel drawings
# load complete
# loading snowflake drawings
# load complete
# loading snowman drawings
# load complete
# loading soccer ball drawings
# load complete
# loading sock drawings
# load complete
# loading speedboat drawings
# load complete
# loading spider drawings
# load complete
# loading spoon drawings
# load complete
# loading spreadsheet drawings
# load complete
# loading square drawings
# load complete
# loading squiggle drawings
# load complete
# loading squirrel drawings
# load complete
# loading stairs drawings
# load complete
# loading star drawings
# load complete
# loading steak drawings
# load complete
# loading stereo drawings
# load complete
# loading stethoscope drawings
# load complete
# loading stitches drawings
# load complete
# loading stop sign drawings
# load complete
# loading stove drawings
# load complete
# loading strawberry drawings
# load complete
# loading streetlight drawings
# load complete
# loading string bean drawings
# load complete
# loading submarine drawings
# load complete
# loading suitcase drawings
# load complete
# loading sun drawings
# load complete
# loading swan drawings
# load complete
# loading sweater drawings
# load complete
# loading swing set drawings
# load complete
# loading sword drawings
# load complete
# loading syringe drawings
# load complete
# loading t-shirt drawings
# load complete
# loading table drawings
# load complete
# loading teapot drawings
# load complete
# loading teddy-bear drawings
# load complete
# loading telephone drawings
# load complete
# loading television drawings
# load complete
# loading tennis racquet drawings
# load complete
# loading tent drawings
# load complete
# loading The Eiffel Tower drawings
# load complete
# loading The Great Wall of China drawings
# load complete
# loading The Mona Lisa drawings
# load complete
# loading tiger drawings
# load complete
# loading toaster drawings
# load complete
# loading toe drawings
# load complete
# loading toilet drawings
# load complete
# loading tooth drawings
# load complete
# loading toothbrush drawings
# load complete
# loading toothpaste drawings
# load complete
# loading tornado drawings
# load complete
# loading tractor drawings
# load complete
# loading traffic light drawings
# load complete
# loading train drawings
# load complete
# loading tree drawings
# load complete
# loading triangle drawings
# load complete
# loading trombone drawings
# load complete
# loading truck drawings
# load complete
# loading trumpet drawings
# load complete
# loading umbrella drawings
# load complete
# loading underwear drawings
# load complete
# loading van drawings
# load complete
# loading vase drawings
# load complete
# loading violin drawings
# load complete
# loading washing machine drawings
# load complete
# loading watermelon drawings
# load complete
# loading waterslide drawings
# load complete
# loading whale drawings
# load complete
# loading wheel drawings
# load complete
# loading windmill drawings
# load complete
# loading wine bottle drawings
# load complete
# loading wine glass drawings
# load complete
# loading wristwatch drawings
# load complete
# loading yoga drawings
# load complete
# loading zebra drawings
# load complete
# loading zigzag drawings
# load complete

# %%
# COCO label name -> label info
label_info_from_coco_name = {}
for row in label_info.itertuples():
    label_info_from_coco_name[row.coco_label] = row

# %%
@dataclass
class Draw:
    drawing: QuickDrawing
    position: tuple[int, int]


@dataclass
class Draws:
    drawings: list[Draw]
    filename: str

    def get_animation(self, margin=100, down_scale=3, in_text=True):
        canvas = Image.new('RGB', (640, 480), (255, 255, 255))
        canvas = self.__add_margin(canvas, margin, margin, margin, margin, (255, 255, 255))
        images = []
        for draw in self.drawings:
            draw_image = draw.drawing.get_image(stroke_width=2 * down_scale)
            mask_image = self.__get_mask(draw_image, (0, 0, 0))
            draw_image = draw_image.resize((draw_image.width // down_scale, draw_image.height // down_scale))
            mask_image = mask_image.resize((mask_image.width // down_scale, mask_image.height // down_scale))
            canvas.paste(
                draw_image, 
                (draw.position[0] - (draw_image.width // 2) + margin, draw.position[1] - (draw_image.height // 2) + margin),
                mask=mask_image)
            image_draw = ImageDraw.Draw(canvas)
            image_draw.text(
                (draw.position[0] + margin, draw.position[1] + (draw_image.height // 2) + margin),
                draw.drawing.name,
                fill='black',
                font=ImageFont.truetype(font='/System/Library/Fonts/Helvetica.ttc', size=18))
            images.append(canvas.copy())
        return images
    
    def save_animation(self, filename, duration=40, loop=0):
        animation = self.get_animation()
        animation[0].save(filename, save_all=True, append_images=animation[1:], optimize=False, duration=duration, loop=loop)
    
    def save(self, filename):
        animation = self.get_animation()
        animation[-1].save(filename)
    
    def __add_margin(self, pil_img, top, right, bottom, left, color):
        width, height = pil_img.size
        new_width = width + right + left
        new_height = height + top + bottom
        result = Image.new(pil_img.mode, (new_width, new_height), color)
        result.paste(pil_img, (left, top))
        return result
    
    def __get_mask(self, image, color):
        r, g, b = image.split()
        _r = r.point(lambda _: 1 if _ == color[0] else 0, mode="1")
        _g = g.point(lambda _: 1 if _ == color[1] else 0, mode="1")
        _b = b.point(lambda _: 1 if _ == color[2] else 0, mode="1")
        mask = ImageChops.logical_and(_r, _g)
        mask = ImageChops.logical_and(mask, _b)
        return mask

# %%
def generate_drawings(index=None, min_objects=2, seed=None, erosion=None):
    # set seed
    random.seed(seed)
    np.random.seed(seed)
    # get random coco info
    coco = list(coco_info.query(f'num>={min_objects}').sample(random_state=seed).itertuples())[0] if not index else list(coco_info[index:index+1].itertuples())[0]
    # get coco image
    image = np.asarray(Image.open(f"../{coco.name}"))
    # iterate objects and create sequence
    drawings = []
    for coco_name in coco.objects.split(", "):
        # get label info
        label = label_info_from_coco_name[coco_name]
        # if erosion
        if erosion:
            # TODO: erosion
            pass
        # get random position of object from image
        pos = random.choice(list(zip(*np.where(image == label.id - 1))))
        # get quick draw strokes
        name = random.choice(label.quick_draw_labels.split(", "))
        drawings.append(Draw(qd.get_drawing(name), (pos[1], pos[0])))
    random.shuffle(drawings)
    return Draws(drawings, coco.name)

# %%
draws = generate_drawings(index=888, min_objects=10, seed=67)
pprint(asdict(draws))
filename = os.path.splitext(os.path.basename(draws.filename))[0]
draws.save_animation(f'{filename}.gif', duration=800)
draws.save(f'{filename}.png')
# Out:
# {'drawings': [{'drawing': <quickdraw.data.QuickDrawing object at 0x17aa63670>,
#                'position': (407, 83)},
#               {'drawing': <quickdraw.data.QuickDrawing object at 0x17aa635e0>,
#                'position': (476, 186)},
#               {'drawing': <quickdraw.data.QuickDrawing object at 0x17aafecd0>,
#                'position': (46, 308)},
#               {'drawing': <quickdraw.data.QuickDrawing object at 0x17aafeaf0>,
#                'position': (223, 185)}],
#  'filename': 'data/stuffthingmaps_trainval2017/val2017/000000450758.png'}

# %%
for i in range(1, 101):
    draws = generate_drawings(index=888, min_objects=10, seed=i)
    draws.save(f'{filename}-{i}.png')
