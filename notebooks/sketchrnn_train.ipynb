# %% [markdown]
# <a href="https://colab.research.google.com/github/stwind/SketchRNN_tf2/blob/master/notebooks/train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Setup

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'


import os
import sys
import math
import time
import numpy as np
import tensorflow as tf
from tqdm import tqdm, trange
from matplotlib import pyplot as plt
from tensorflow import keras as K

print("tf: {}".format(tf.version.VERSION))
print("tf.keras: {}".format(K.__version__))
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# tf: 2.1.0
# tf.keras: 2.2.4-tf
# Num GPUs Available:  1

# %%
sys.path.append('../SketchRNN_tf2')
from sketchrnn import models, dataset, utils

# %% [markdown]
# ## Data

# %%
data_class = 'airplane' #@param ["cat","eye","rabbit"]

data = np.load(f'../data/sketch_rnn/{data_class}.npz',encoding='latin1',allow_pickle=True)

# %%
data_train = [dataset.cleanup(d) for d in data['train']]
data_valid = [dataset.cleanup(d) for d in data['valid']]
data_test = [dataset.cleanup(d) for d in data['test']]

# %%
n = [4, 10]

fig, ax = plt.subplots(n[0],n[1],figsize=(14, 6))

perm = np.random.permutation(range(len(data_train)))[:n[0]*n[1]]

for i, idx in enumerate(perm):
    x, y = i // n[1], i % n[1]
    utils.plot_strokes(ax[x][y], data_train[idx])
    ax[x][y].set(xlabel=idx)
    
utils.plt_show()

# %% [markdown]
# ## Models

# %%
hps = {
    "max_seq_len": max(map(len, np.concatenate([data['train'], data['valid'], data['test']]))),
    'batch_size': 100,
    "num_batches": math.ceil(len(data_train) / 100),
    "epochs": 100,
    "recurrent_dropout_prob": 0.1, ## 0.0 for gpu lstm
    "enc_rnn_size": 256,
    "dec_rnn_size": 512,
    "z_size": 128,
    "num_mixture": 20,
    "learning_rate": 0.001,
    "min_learning_rate": 0.00001,
    "decay_rate": 0.9999,
    "grad_clip": 1.0,
    'kl_tolerance': 0.2,
    'kl_decay_rate': 0.99995,
    "kl_weight": 0.5,
    'kl_weight_start': 0.01,
}

# %%
sketchrnn = models.SketchRNN(hps)
sketchrnn.models['full'].summary()
# Out:
# Model: "sketchrnn"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input (InputLayer)      [(None, 99, 5)]      0
# __________________________________________________________________________________________________
# encoder (Model)                 [(None, 128), (None, 667904      encoder_input[0][0]
# __________________________________________________________________________________________________
# decoder_input (InputLayer)      [(None, None, 5)]    0
# __________________________________________________________________________________________________
# initial_state (Model)           [(None, 512), (None, 132096      encoder[1][0]
# __________________________________________________________________________________________________
# decoder (Model)                 [(None, None, 123),  1386107     decoder_input[0][0]
#                                                                  encoder[1][0]
#                                                                  initial_state[1][0]
#                                                                  initial_state[1][1]
# ==================================================================================================
# Total params: 2,186,107
# Trainable params: 2,186,107
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Training

# %%
scale_factor = dataset.calc_scale_factor(data_train)

train_dataset = dataset.make_train_dataset(data_train, hps['max_seq_len'], hps['batch_size'], scale_factor)
val_dataset = dataset.make_val_dataset(data_valid, hps['max_seq_len'], hps['batch_size'], scale_factor)

# %%
checkpoint_dir = '../data/sketchrnn/checkpoints'
log_dir = '../data/sketchrnn/logs'

# !mkdir -p "{log_dir}" "{checkpoint_dir}"

initial_epoch = 0 #@param {type: "number"}
initial_loss = 0.05 #@param {type: "number"}
checkpoint = os.path.join(checkpoint_dir, 'sketch_rnn_' + data_class + '_weights.{:02d}_{:.2f}.hdf5')

if initial_epoch > 0:
    sketchrnn.load_weights(checkpoint.format(initial_epoch, initial_loss))

# %%
sketchrnn.train(initial_epoch, train_dataset, val_dataset, checkpoint)
# Out:
# [train] epoch: 1/100, batch: 100, recon: 0.9471, kl: 1.1012, cost: 0.9608, lr: 0.000990, klw: 0.0124, time: 24.17
# [train] epoch: 1/100, batch: 200, recon: 0.7492, kl: 1.1629, cost: 0.7665, lr: 0.000980, klw: 0.0149, time: 20.86
# [train] epoch: 1/100, batch: 300, recon: 0.6733, kl: 1.1428, cost: 0.6931, lr: 0.000971, klw: 0.0173, time: 20.80
# [train] epoch: 1/100, batch: 400, recon: 0.6278, kl: 0.9974, cost: 0.6474, lr: 0.000961, klw: 0.0197, time: 20.82
# [train] epoch: 1/100, batch: 500, recon: 0.5956, kl: 1.0189, cost: 0.6181, lr: 0.000952, klw: 0.0221, time: 20.84
# [train] epoch: 1/100, batch: 600, recon: 0.5925, kl: 0.9928, cost: 0.6168, lr: 0.000942, klw: 0.0245, time: 20.80
# [train] epoch: 1/100, batch: 700, recon: 0.4878, kl: 0.8824, cost: 0.5115, lr: 0.000933, klw: 0.0269, time: 20.69
# [validate] epoch: 1/100, recon: 0.4194, kl: 0.9118, cost: 0.4439
# [train] epoch: 2/100, batch: 100, recon: 0.5633, kl: 0.9578, cost: 0.5913, lr: 0.000924, klw: 0.0292, time: 20.88
# [train] epoch: 2/100, batch: 200, recon: 0.4955, kl: 0.8668, cost: 0.5229, lr: 0.000915, klw: 0.0316, time: 20.84
# [train] epoch: 2/100, batch: 300, recon: 0.4706, kl: 0.8494, cost: 0.4993, lr: 0.000906, klw: 0.0339, time: 20.84
# [train] epoch: 2/100, batch: 400, recon: 0.4625, kl: 0.8087, cost: 0.4918, lr: 0.000897, klw: 0.0362, time: 20.83
# [train] epoch: 2/100, batch: 500, recon: 0.3903, kl: 0.7726, cost: 0.4201, lr: 0.000888, klw: 0.0385, time: 20.86
# [train] epoch: 2/100, batch: 600, recon: 0.3865, kl: 0.7670, cost: 0.4179, lr: 0.000879, klw: 0.0408, time: 20.91
# [train] epoch: 2/100, batch: 700, recon: 0.3960, kl: 0.7254, cost: 0.4273, lr: 0.000871, klw: 0.0431, time: 20.74
# [validate] epoch: 2/100, recon: 0.2825, kl: 0.7484, cost: 0.3148
# [train] epoch: 3/100, batch: 100, recon: 0.3354, kl: 0.7233, cost: 0.3682, lr: 0.000862, klw: 0.0454, time: 20.91
# [train] epoch: 3/100, batch: 200, recon: 0.3911, kl: 0.6766, cost: 0.4233, lr: 0.000854, klw: 0.0477, time: 20.79
# [train] epoch: 3/100, batch: 300, recon: 0.4123, kl: 0.6791, cost: 0.4462, lr: 0.000845, klw: 0.0499, time: 20.84
# [train] epoch: 3/100, batch: 400, recon: 0.3376, kl: 0.6726, cost: 0.3727, lr: 0.000837, klw: 0.0522, time: 20.81
# [train] epoch: 3/100, batch: 500, recon: 0.3641, kl: 0.6663, cost: 0.4004, lr: 0.000829, klw: 0.0544, time: 20.81
# [train] epoch: 3/100, batch: 600, recon: 0.3910, kl: 0.6514, cost: 0.4279, lr: 0.000821, klw: 0.0566, time: 20.81
# [train] epoch: 3/100, batch: 700, recon: 0.3364, kl: 0.6392, cost: 0.3740, lr: 0.000812, klw: 0.0588, time: 20.71
# [validate] epoch: 3/100, recon: 0.2098, kl: 0.6583, cost: 0.2486
# [train] epoch: 4/100, batch: 100, recon: 0.3762, kl: 0.6520, cost: 0.4160, lr: 0.000804, klw: 0.0610, time: 20.89
# [train] epoch: 4/100, batch: 200, recon: 0.2784, kl: 0.6080, cost: 0.3169, lr: 0.000797, klw: 0.0632, time: 20.85
# [train] epoch: 4/100, batch: 300, recon: 0.2671, kl: 0.6146, cost: 0.3073, lr: 0.000789, klw: 0.0654, time: 20.79
# [train] epoch: 4/100, batch: 400, recon: 0.2837, kl: 0.6040, cost: 0.3246, lr: 0.000781, klw: 0.0676, time: 20.87
# [train] epoch: 4/100, batch: 500, recon: 0.2960, kl: 0.6278, cost: 0.3398, lr: 0.000773, klw: 0.0697, time: 20.80
# [train] epoch: 4/100, batch: 600, recon: 0.3229, kl: 0.6124, cost: 0.3669, lr: 0.000766, klw: 0.0719, time: 20.78
# [train] epoch: 4/100, batch: 700, recon: 0.2754, kl: 0.6099, cost: 0.3206, lr: 0.000758, klw: 0.0740, time: 20.67
# [validate] epoch: 4/100, recon: 0.1472, kl: 0.6224, cost: 0.1933
# [train] epoch: 5/100, batch: 100, recon: 0.2499, kl: 0.5973, cost: 0.2953, lr: 0.000751, klw: 0.0761, time: 20.85
# [train] epoch: 5/100, batch: 200, recon: 0.2513, kl: 0.6086, cost: 0.2989, lr: 0.000743, klw: 0.0783, time: 20.84
# [train] epoch: 5/100, batch: 300, recon: 0.2619, kl: 0.6001, cost: 0.3101, lr: 0.000736, klw: 0.0804, time: 20.85
# [train] epoch: 5/100, batch: 400, recon: 0.2321, kl: 0.5898, cost: 0.2807, lr: 0.000729, klw: 0.0825, time: 20.82
# [train] epoch: 5/100, batch: 500, recon: 0.2497, kl: 0.6013, cost: 0.3006, lr: 0.000722, klw: 0.0845, time: 20.88
# [train] epoch: 5/100, batch: 600, recon: 0.2232, kl: 0.6028, cost: 0.2754, lr: 0.000715, klw: 0.0866, time: 20.83
# [train] epoch: 5/100, batch: 700, recon: 0.2235, kl: 0.5747, cost: 0.2745, lr: 0.000708, klw: 0.0887, time: 20.71
# [validate] epoch: 5/100, recon: 0.1012, kl: 0.5895, cost: 0.1535
# [train] epoch: 6/100, batch: 100, recon: 0.2363, kl: 0.5903, cost: 0.2899, lr: 0.000701, klw: 0.0907, time: 20.90
# [train] epoch: 6/100, batch: 200, recon: 0.2623, kl: 0.5915, cost: 0.3172, lr: 0.000694, klw: 0.0928, time: 20.82
# [train] epoch: 6/100, batch: 300, recon: 0.1745, kl: 0.5824, cost: 0.2297, lr: 0.000687, klw: 0.0948, time: 20.82
# [train] epoch: 6/100, batch: 400, recon: 0.2346, kl: 0.5767, cost: 0.2905, lr: 0.000680, klw: 0.0968, time: 20.85
# [train] epoch: 6/100, batch: 500, recon: 0.2004, kl: 0.5902, cost: 0.2588, lr: 0.000674, klw: 0.0988, time: 20.83
# [train] epoch: 6/100, batch: 600, recon: 0.2183, kl: 0.5884, cost: 0.2777, lr: 0.000667, klw: 0.1008, time: 20.83
# [train] epoch: 6/100, batch: 700, recon: 0.1878, kl: 0.5876, cost: 0.2482, lr: 0.000660, klw: 0.1028, time: 20.67
# [validate] epoch: 6/100, recon: 0.0623, kl: 0.5974, cost: 0.1237
# [train] epoch: 7/100, batch: 100, recon: 0.1936, kl: 0.5809, cost: 0.2545, lr: 0.000654, klw: 0.1048, time: 20.84
# [train] epoch: 7/100, batch: 200, recon: 0.2308, kl: 0.5893, cost: 0.2938, lr: 0.000648, klw: 0.1068, time: 20.81
# [train] epoch: 7/100, batch: 300, recon: 0.1631, kl: 0.5830, cost: 0.2265, lr: 0.000641, klw: 0.1087, time: 20.83
# [train] epoch: 7/100, batch: 400, recon: 0.2199, kl: 0.5684, cost: 0.2828, lr: 0.000635, klw: 0.1107, time: 20.86
# [train] epoch: 7/100, batch: 500, recon: 0.1615, kl: 0.5791, cost: 0.2267, lr: 0.000629, klw: 0.1126, time: 20.80
# [train] epoch: 7/100, batch: 600, recon: 0.1821, kl: 0.5682, cost: 0.2472, lr: 0.000623, klw: 0.1146, time: 20.84
# [train] epoch: 7/100, batch: 700, recon: 0.1431, kl: 0.5704, cost: 0.2095, lr: 0.000616, klw: 0.1165, time: 20.69
# [validate] epoch: 7/100, recon: 0.0350, kl: 0.5752, cost: 0.1020
# [train] epoch: 8/100, batch: 100, recon: 0.2525, kl: 0.5752, cost: 0.3206, lr: 0.000610, klw: 0.1184, time: 20.90
# [train] epoch: 8/100, batch: 200, recon: 0.1588, kl: 0.5770, cost: 0.2282, lr: 0.000604, klw: 0.1203, time: 20.82
# [train] epoch: 8/100, batch: 300, recon: 0.1520, kl: 0.5614, cost: 0.2206, lr: 0.000599, klw: 0.1222, time: 20.83
# [train] epoch: 8/100, batch: 400, recon: 0.1672, kl: 0.5754, cost: 0.2386, lr: 0.000593, klw: 0.1241, time: 20.82
# [train] epoch: 8/100, batch: 500, recon: 0.1482, kl: 0.5741, cost: 0.2205, lr: 0.000587, klw: 0.1259, time: 20.82
# [train] epoch: 8/100, batch: 600, recon: 0.1764, kl: 0.5606, cost: 0.2481, lr: 0.000581, klw: 0.1278, time: 20.84
# [train] epoch: 8/100, batch: 700, recon: 0.1851, kl: 0.5693, cost: 0.2589, lr: 0.000575, klw: 0.1297, time: 20.70
# [validate] epoch: 8/100, recon: 0.0134, kl: 0.5763, cost: 0.0881
# [train] epoch: 9/100, batch: 100, recon: 0.1619, kl: 0.5641, cost: 0.2361, lr: 0.000570, klw: 0.1315, time: 20.88
# [train] epoch: 9/100, batch: 200, recon: 0.1010, kl: 0.5771, cost: 0.1779, lr: 0.000564, klw: 0.1334, time: 20.83
# [train] epoch: 9/100, batch: 300, recon: 0.1452, kl: 0.5691, cost: 0.2221, lr: 0.000559, klw: 0.1352, time: 20.86
# [train] epoch: 9/100, batch: 400, recon: 0.0839, kl: 0.5675, cost: 0.1616, lr: 0.000553, klw: 0.1370, time: 20.83
# [train] epoch: 9/100, batch: 500, recon: 0.0966, kl: 0.5726, cost: 0.1761, lr: 0.000548, klw: 0.1388, time: 20.80
# [train] epoch: 9/100, batch: 600, recon: 0.1103, kl: 0.5644, cost: 0.1897, lr: 0.000543, klw: 0.1406, time: 20.84
# [train] epoch: 9/100, batch: 700, recon: 0.1087, kl: 0.5664, cost: 0.1894, lr: 0.000537, klw: 0.1424, time: 20.72
# [validate] epoch: 9/100, recon: -0.0094, kl: 0.5721, cost: 0.0721
# [train] epoch: 10/100, batch: 100, recon: 0.1319, kl: 0.5635, cost: 0.2131, lr: 0.000532, klw: 0.1442, time: 20.86
# [train] epoch: 10/100, batch: 200, recon: 0.0783, kl: 0.5532, cost: 0.1590, lr: 0.000527, klw: 0.1460, time: 20.81
# [train] epoch: 10/100, batch: 300, recon: 0.0901, kl: 0.5595, cost: 0.1727, lr: 0.000522, klw: 0.1477, time: 20.82
# [train] epoch: 10/100, batch: 400, recon: 0.0860, kl: 0.5627, cost: 0.1701, lr: 0.000517, klw: 0.1495, time: 20.81
# [train] epoch: 10/100, batch: 500, recon: 0.0635, kl: 0.5680, cost: 0.1494, lr: 0.000512, klw: 0.1512, time: 20.82
# [train] epoch: 10/100, batch: 600, recon: 0.0956, kl: 0.5633, cost: 0.1817, lr: 0.000507, klw: 0.1530, time: 20.83
# [train] epoch: 10/100, batch: 700, recon: 0.1508, kl: 0.5628, cost: 0.2379, lr: 0.000502, klw: 0.1547, time: 20.71
# [validate] epoch: 10/100, recon: -0.0317, kl: 0.5704, cost: 0.0565
# [train] epoch: 11/100, batch: 100, recon: 0.1306, kl: 0.5638, cost: 0.2188, lr: 0.000497, klw: 0.1564, time: 20.94
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-b6a9bdc743a0> in <module>
# ----> 1 sketchrnn.train(initial_epoch, train_dataset, val_dataset, checkpoint)
#
# ~/tanigaki/i-sketcher/interactive-sketcher/SketchRNN_tf2/sketchrnn/models.py in train(self, initial_epoch, train_dataset, val_dataset, checkpoint, log_every)
#     206                 K.backend.set_value(kl_weight, K.backend.get_value(klw))
#     207
# --> 208                 md_loss, kl_loss, total_loss = train_step(inputs, target)
#     209
#     210                 if batch % log_every == 0:
#
# ~/anaconda3/envs/i-sketcher/lib/python3.6/site-packages/tensorflow_core/python/eager/def_function.py in __call__(self, *args, **kwds)
#     566         xla_context.Exit()
#     567     else:
# --> 568       result = self._call(*args, **kwds)
#     569
#     570     if tracing_count == self._get_tracing_count():
#
# ~/anaconda3/envs/i-sketcher/lib/python3.6/site-packages/tensorflow_core/python/eager/def_function.py in _call(self, *args, **kwds)
#     597       # In this case we have created variables on the first call, so we run the
#     598       # defunned version which is guaranteed to never create variables.
# --> 599       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     600     elif self._stateful_fn is not None:
#     601       # Release the lock early so that multiple threads can perform the call
#
# ~/anaconda3/envs/i-sketcher/lib/python3.6/site-packages/tensorflow_core/python/eager/function.py in __call__(self, *args, **kwargs)
#    2361     with self._lock:
#    2362       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2363     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2364
#    2365   @property
#
# ~/anaconda3/envs/i-sketcher/lib/python3.6/site-packages/tensorflow_core/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1609          if isinstance(t, (ops.Tensor,
#    1610                            resource_variable_ops.BaseResourceVariable))),
# -> 1611         self.captured_inputs)
#    1612
#    1613   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~/anaconda3/envs/i-sketcher/lib/python3.6/site-packages/tensorflow_core/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# ~/anaconda3/envs/i-sketcher/lib/python3.6/site-packages/tensorflow_core/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     543               inputs=args,
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#     547           outputs = execute.execute_with_cancellation(
#
# ~/anaconda3/envs/i-sketcher/lib/python3.6/site-packages/tensorflow_core/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:
